# %%
import numpy as np
import matplotlib.pyplot as plt

#funcion rand: numeros aleatorios en una distribucion uniforme

print(np.random.rand(3,3))

rand = np.random.rand(20000)
plt.hist(rand, bins=30)
plt.show()

#funcion uniform: igual que rand, pero permite ingresar los límites de la 
#muestra.

print(np.random.uniform(low=10, high=20, size=6))

rand = np.random.rand(10000)
plt.hist(rand, bins=60)
plt.show()

uniform = np.random.uniform(low=0, high=1, size=10000)
plt.hist(uniform, bins=50)
plt.show()

#funcion randn: numeros aleatorios en una distribucion
print(np.random.randn(2, 2))


#funccion normal: igual que randn pero permite escalar los limites de la prueba

normal = np.random.randn(10000)
plt.hist(normal, bins=50)
plt.show()

print(np.random.normal(loc=0, scale=2, size=6))

normal2 = np.random.normal(0, 1, 10000)
plt.hist(normal2, bins=50)
plt.show()

#funcion randint: numeros aleatorios entre un rango dado
print(np.random.randint(low=0, high=10, size=(3, 3)))
print(np.random.randint(1,100,10))
# Out:
# [[0.36702176 0.64747194 0.12920048]
#  [0.76705379 0.72869778 0.22469953]
#  [0.15183568 0.11020447 0.99209242]]
# [17.71967264 19.19456761 12.85510637 16.8963329  11.32321075 11.49831388]
# [[ 0.49697777  0.63842857]
#  [-0.78771104  1.02334592]]
# [-2.25662184  1.71390937  2.61450006 -1.94670896 -1.38656648 -0.757663  ]
# [[7 5 9]
#  [9 3 0]
#  [8 1 6]]
# [21  7 12 39 75 14 24 48 21 52]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e00223e1-940a-419b-854e-d5327f2e6aa8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
