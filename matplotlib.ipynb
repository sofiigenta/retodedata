# %%
import pandas as pd

df = pd.read_csv('/work/studentsperformance_f29e92e5-811f-4cf9-9504-91644b0ecc35.csv')

import matplotlib.pyplot as plt

x = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
y= [1,2,5,10,21,40,51]

#graficamos x e y
plt.plot(x,y)

#creamos grafica de linea

#la mostramos
plt.show()

#detalles para mejorar la visualizacion


#marker: marca cada punto de la linea
#linestyle: le pone estilo a la linea
#color: define el color de la linea


plt.plot(x, y, marker='o', linestyle='--', color='g')

plt.show()

#agregamos nombre a cada uno de los ejes
plt.plot(x,y)
plt.xlabel('Years')
plt.ylabel('Revenue')
#le agregamos titulo a la grafica
plt.title('Revenue per years')
plt.plot(x, y, marker='o', linestyle='--', color='g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-43f83a613f28> in <module>
#      34 #le agregamos titulo a la grafica
#      35 plt.title('Revenue per years')
# ---> 36 plt.plot(x, y, marker='o', linestyle='--', color='a')
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
# -> 2759         **({"data": data} if data is not None else {}), **kwargs)
#    2760
#    2761
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e00223e1-940a-419b-854e-d5327f2e6aa8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
